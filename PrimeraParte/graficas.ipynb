# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('remfam2010_2023_datos2.xlsx', index_col=0)
df
#"""En este excel podemos apreciar las operaciones realizadas que nos permiten obtener la taza de crecimiento trimestral,
#crecimiento interanual entre trimestres y media movil de los 6 meses"""
# Out:
#                    2002.0    2003.0    2004.0     2005.0    2006.0    2007.0  \
# Unnamed: 0
# Enero            0.052650  0.078213  0.076352   0.069984  0.068952  0.069543
# Febrero          0.061200  0.068713  0.072037   0.068092  0.070584  0.065871
# Marzo            0.069035  0.076325  0.089349   0.082352  0.080050  0.079362
# Abril            0.088143  0.085966  0.079986   0.084565  0.078796  0.080812
# Mayo             0.056827  0.088951  0.082639   0.091646  0.100114  0.095179
# Junio            0.081029  0.076665  0.083168   0.087244  0.085904  0.086346
# Julio            0.086442  0.091125  0.081005   0.082132  0.083906  0.092324
# Agosto           0.102766  0.084934  0.083423   0.080835  0.092233  0.092387
# Septiembre       0.099620  0.083812  0.083030   0.080721  0.081169  0.079147
# Octubre          0.111600  0.090140  0.085480   0.092939  0.093746  0.094751
# Noviembre        0.090526  0.082305  0.092804   0.088748  0.081625  0.082549
# ...

# %% [markdown]
# ### Graficas 2002
# Grafica de Media Movil de 6 meses en 2002

# %%
# Seleccionar las filas y columnas que deseas graficar
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2002.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses en 2002')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Grafica de crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2002.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Grafica de crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2002.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Grafica de valores normalizados

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2002.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# ### Graficas 2003
# Graficas de valores normalizados

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2003.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2003.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2003.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media movil entre 6 meses

# %%
# Seleccionar las filas y columnas que deseas graficar
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2003.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Graficas 2004

# %% [markdown]
# Grafica de valores normalizados

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2004.0']

# Crear la gráfica de pie

plt.pie(datos.values, labels=datos.index, autopct='%1.1f%%', textprops={'color': 'white'})
plt.title('Valores de remesas normalizados', color = 'white')

# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', color='white')
ax.tick_params(axis='y', color='white')
plt.xticks(rotation=90, color='white')
plt.show()

# %% [markdown]
# Grafica de crecimientro trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2004.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual trimestral

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2004.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media Movil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2004.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Graficas 2005

# %% [markdown]
# Grafica de valores normalizados

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2005.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2005.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2005.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2005.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Graficas 2006

# %% [markdown]
# Grafica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2006.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2006.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2006.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media movil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2006.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2007

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2007.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2007.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2007.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2007.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2008

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2008.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2008.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2008.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2008.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2009

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2009.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2009.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2009.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2009.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2010

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2010.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2010.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2010.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2010.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2011

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2011.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2011.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2011.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2011.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2012

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2012.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2012.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2012.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2012.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas de 2013

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2013.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2013.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2013.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2013.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2014

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2014.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2014.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2014.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2014.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2015

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2015.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2015.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2015.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2015.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2016

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2016.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2016.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2016.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2016.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas de 2017

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2017.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2017.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2017.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2017.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2018

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2018.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2018.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2018.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2018.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráfica de 2019

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2019.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2019.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2019.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2019.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas de 2020

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2020.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2020.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2020.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2020.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2021

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2021.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2021.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2021.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2021.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2022

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2022.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()

# %% [markdown]
# Crecimiento trimestral

# %%
datos = df.loc[['Q1','Q2','Q3','Q4'], '2022.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Datos de crecimiento trimestral')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Crecimiento interanual entre trimestres

# %%
datos = df.loc[['TCAQ1','TCAQ2','TCAQ3','TCAQ4'], '2022.0']

# Crear la gráfica de barras
plt.plot(datos.index, datos.values)
plt.title('Datos de crecimiento interanual entre trimestres')
plt.xlabel('Trimestres') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# Media móvil de 6 meses

# %%
datos = df.loc[['MM_ENE','MM_FEB','MM_MAR','MM_ABRIL','MM_MAY','MM_JUN','MM_JUL','MM_AG','MM_SEP','MM_OCT','MM_NOV','MM_DIC'], '2022.0']

# Crear la gráfica
plt.plot(datos)
plt.title('Datos de Media Movil de 6 meses')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

plt.show()

# %% [markdown]
# ### Gráficas 2023

# %% [markdown]
# Gráfica de valores

# %%
datos = df.loc[['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre'], '2023.0']

# Crear la gráfica de barras
plt.bar(datos.index, datos.values)
plt.title('Valores de remesas normalizados')
plt.xlabel('Meses') 
plt.ylabel('Datos')
plt.xticks(rotation = '90')
# Hacer que las regletas sean blancas
ax = plt.gca()
ax.spines['top'].set_color('white')
ax.spines['bottom'].set_color('white')
ax.spines['left'].set_color('white')
ax.spines['right'].set_color('white')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.show()
